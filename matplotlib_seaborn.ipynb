# %% [markdown]
# # La importancia de la visualizacion de datos

# %% [markdown]
# ### Cual es la importancia de la visualizacion de datos?
#
# Visualizar los datos te da respuestas a preguntas que ni sabias que tenias.
#
#
# - Permite mayor contexto.
# - Nos permite encontrar hallazgos de una manera muy sencilla, por ejemplo: encontrar tendencias, comportamientos en los datos, detectar outliers (datos atipicos)
# - Permite mayor claridad en el codigo, en la Ciencia de Datos orientada a ML o IA es utilizada para las lineas de entrenamiento, lo que hace mas facil de enternder los algoritmos de manera facil a traves de visualizaciones.

# %% [markdown]
# ### Matplotlib
#
# Creada en 2003 por John D. Hunter.
#
# - Basada en Numpy.
# - Emula comandos de MATLAB.
# - Escrita en Python.
# - Es rapida.
# - Sus graficas son personalizables.
#
# ### Seaborn
#
# Es una libreria montada sobre matplotlib que tambien nos ayuda en la visualizacion de datos.

# %% [markdown]
# [Slides del curso](https://static.platzi.com/media/public/uploads/slides-del-curso-basico-de-matplotlib-seaborn_4b3154c1-b356-455d-a129-8358bcafa19d.pdf)
#
# [Cheatsheets](https://matplotlib.org/cheatsheets/)
#
# [Quick start guide](https://matplotlib.org/stable/tutorials/introductory/quick_start.html)
#
# [Tutorial Matplotlib](https://platzi.com/blog/matplotlib/)
#
# [Ejemplos](https://matplotlib.org/stable/gallery/index.html)

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Pyplot básico

# %% [markdown]
# Pyplot es una funcionalidad que tiene Matplotlib para ejecutar graficas de manera sencilla.

# %%
# Importamos las librerias
import numpy as np
import matplotlib.pyplot as plt

# %%
# Definimos las variables para las funciones
x = np.linspace(0, 5, 11)
y = x**2

# %%
# Graficas de linea
plt.plot(x, y, 'bo')
plt.show()

# %%
plt.plot(x, y, 'rs-')
plt.show()

# %%
plt.plot(x, y, 'yD:') #color amarillo, marker diamante, puntos consecutivos
plt.show()

# %% [markdown]
# **Colors**:
#
# ‘b’	blue
#
# ‘g’	green
#
# ‘m’	magenta

# %% [markdown]
# **Markers**:
#
#
# ‘.’	point marker
#
# ‘,’	pixel marker
#
# ‘o’	circle marker
#
# ‘v’	triangle_down marker
#
# ‘^’	triangle_up marker
#
# ‘<’	triangle_left marker
#
# ‘>’	triangle_right marker

# %% [markdown]
# **Line Styles**:
#
# ‘-’	solid line style
#
# ‘–’	dashed line style
#
# ‘-.’	dash-dot line style
#
# ‘:’	dotted line style

# %%
# Histograma
plt.hist(x)
plt.show()

# %%
# Pie chart
plt.pie(x)
plt.show()

# %%
# Scatter plot - Relacion entre dos variables
plt.scatter(x, y)
plt.show()

# %%
# Box plot - Distribucion de los datos
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### Subplot

# %% [markdown]
# [Subplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html) permite crear gráficos dentro de una gráfica. Esto lo hace a través de una matriz de gráficos y se puede acceder a ellos a través de índices:
#
# plt.subplot(row, column, index)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 101)
y = x ** 2

#plt.figure(figsize=(5,5)) #(width, height)

# Grafico 1
plt.subplot(2, 2, 1)
plt.plot(x, y, 'b:') # PLot 1
plt.plot(y, x, 'r--') # Plot 2
# Grafico 2
plt.subplot(2, 2, 2)
plt.hist(y) # Plot 3
plt.axhline(10, color='springgreen', linestyle=':') # Plot 4
# Grafico 3
plt.subplot(2, 2, 3)
plt.bar(['F', 'M'], [16, 38], color=['pink', 'cyan']) # Plot 5
# Grafico 4
plt.subplot(2, 2, 4)
plt.pie([1, 7], labels=['b', 'o'])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Metodo orientado a objetos

# %% [markdown]
# Tenemos distintas maneras de mostrar graficas o visualizaciones dentro de Matplotlib, una de ellas es **Pyplot** es sencillo, pero es dificil de customizar y dificil de llegar a mas de una figura o entrar a ciertos detalles. Por otro lado esta el **Orientado a objetos** es mas complejo y necesita mas de codigo, pero brinda una mayor personalizacion, nos permite crear distintos tipos de graficos y distintos tipos de distribucion en uno solo.
#
# Pyplot:
# - Rapido
# - Facil
# - Una sola figura
#
# Object Oriented:
# - Mayor personalizacion
# - Mas amigables a multiples diagramas
# - Mas codigo

# %% [markdown]
# Un objeto define una **Figure** (lienzo) el cual contendra graficas que las llamaremos **Axes**, estos Axes pueden tener diferentes ejes (Axis).

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 101)
y = x**2

fig = plt.figure() # lienzo de las graficas
# los axes son las graficas dentro del lienzo (figure)
axes1 = fig.add_axes([1, 1, 0.5, 0.4]) # [row, column, width, height]
axes2 = fig.add_axes([1.05, 1.15, 0.2, 0.2])
axes1.plot(x, y, 'mediumslateblue')
axes2.plot(y, x, 'cyan')
axes2.set_facecolor('#333')
plt.show()

# %% [markdown]
# ### Subplots

# %% [markdown]
# Sirve para trabajar multiples graficas en un solo lienzo, solo que **Subplots** aprovecha las bondades de trabajar con el metodo orientado a objetos de Matplotlib.

# %%
# Subplots
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 101)
y = np.sin(x)

plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.plot(x, y, 'mediumslateblue')
plt.show()

# %%
import matplotlib.pyplot as plt

x = np.linspace(0,10,101)
y = np.cos(x)

fig, ax = plt.subplots(nrows=1, ncols=2)
# se pueden acceder a los axes como si de arrays se tratasen
ax[0].plot(x, y, 'b')
ax[1].plot(y, x, 'r')
plt.show()

# %%
import matplotlib.pyplot as plt

x = np.linspace(0,10,101)
y = np.cos(x)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# se pueden acceder a los axes por medio de la desestructuracion 
ax1.plot(x, y, 'b')
ax2.plot(y, x, 'r')
fig.tight_layout() #mejora la visualización de los ejes de cada gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10, 101)
y = np.sin(x)

plt.style.use('ggplot')
fig, axes = plt.subplots(nrows=2, ncols=3)
axes[0,0].plot(x,y, 'g')
axes[0,1].plot(y,x, 'orange')
axes[0,2].hist(x, color='b')
axes[1,0].pie(x)
axes[1,1].scatter(x,y)
axes[1,2].boxplot(x)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Leyendas, etiquetas, titulos, tamaño

# %% [markdown]
# Para darle contexto a nuestros graficos necesitamos usar titulos, leyendas, tamaño, etiquetas, para que nuestra grafica tenga un contexto mas amplio.

# %%
# utilizando subplots()
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5,11)
y = np.sin(x)

plt.style.use('ggplot')
fig, axes = plt.subplots(1,2, figsize=(7,4)) # figsize defe la dimension del lienzo
axes[0].plot(x,y, label='sin(x)') # definimos las etiquetas con label
axes[0].set_title('x vs y') # titulos
axes[0].set_xlabel('x') # titulo eje x
axes[0].set_ylabel('y') # titulo eje y
axes[0].legend(loc='lower left') # muestra las leyendas
axes[1].plot(y,x, 'b', label='x')
axes[1].set_title('y vs x')
axes[1].set_xlabel('y')
axes[1].set_ylabel('x')
axes[1].legend()
plt.show()

# %%
# utilizando pyplot
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5,11)
y = np.cos(x)

plt.style.use('ggplot')
plt.plot(x, y, label='$cos(x)$') # los $ le dan una notacion matematica
plt.title('x vs y')
plt.xlabel('x')
plt.ylabel('y')
# con bbox podemos cambiar el tamaño y ubicacion de la leyenda
plt.legend(loc='upper center', bbox_to_anchor=(1.1,1)) 
plt.show()

# %% [markdown]
# Otros valores de *loc* de **[legend()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)**:
# - upper right
# - upper left
# - lower left
# - lower right
# - right
# - left
# - center

# %% [markdown]
# ### Colores y estilos

# %% [markdown]
# [Matplotlib - Specifying colors](https://matplotlib.org/3.5.1/tutorials/colors/colors.html)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5,11)
# para conocer todos los estilos disponibles
print(plt.style.available)
# para definir un estilo
plt.style.use('dark_background')
fig, axes = plt.subplots(figsize=(4,4))
axes.plot(x,x, 'bo--') # estilo matlab
axes.plot(x,x+1, color='cyan', alpha=0.6, linewidth=5, linestyle='dashed') # estilo pyplot
axes.plot(x,x+2, color='purple', linestyle=':', marker='v', markersize=8, markerfacecolor='y')
plt.tight_layout()
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Bar Plot

# %% [markdown]
# Bar plot o grafica de barras, es un tipo de grafica que nos permite graficar variables categoricas.
#
# [bar()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html)
#
# [barh()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html)

# %%
# bar plot
import matplotlib.pyplot as plt
import numpy as np

country = ['Italy', 'Japan', 'Mexico', 'Germany', 'China']
population = [100, 300, 800, 400, 999]

plt.style.use('ggplot')
plt.figure(figsize=(6,4))
plt.bar(country, population, width=0.4,  color=['violet','mediumslateblue'])
plt.title('Poblacion')
plt.ylabel('poblacion en millones')
plt.xlabel('paises')
# para cambiar los valores del eje x (lista_indices, valores_nuevos)
plt.xticks(np.arange(5), ('Italia', 'Japon', 'Mexico', 'Alemania', 'China'), rotation=360-25)
plt.tight_layout()
plt.show()

# %%
# horizontal bar plot
import matplotlib.pyplot as plt
import numpy as np

country = ['Italy', 'Japan', 'Mexico', 'Germany', 'China']
population = [100, 300, 800, 400, 999]

plt.style.use('ggplot')
plt.figure(figsize=(6,4))
plt.barh(country, population, height=0.4)
plt.title('Poblacion')
plt.xlabel('poblacion en millones')
plt.ylabel('paises')
plt.yticks(np.arange(5), ('Italia', 'Japon', 'Mexico', 'Alemania', 'China'))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Crear otro tipo de graficas

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randint(1,50,100)

# %% [markdown]
# [Hist](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html)
#
# Muestra la distribucion de los datos.

# %%
plt.hist(data, bins=5) # bins son el numero de barras para los rangos de frecuencia
plt.show()

# %% [markdown]
# [Boxplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.boxplot.html#matplotlib.axes.Axes.boxplot)
#
# Nos permite ver como es la distribucion de nuestros datos.
#
# Es util para identificar outliers (datos anomalos)
#
# [Explicacion bloxplot](https://www.labxchange.org/library/items/lb:LabXchange:d8863c77:html:1)

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True, medianprops={'color': 'orange'})
plt.show()

# la linea azul representa la mediana o percentil 50
# los extremos de la caja abarcan el 50%
# cada linea fuera de la caja abarca un 25% cada una

# %% [markdown]
# [Scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html#matplotlib.axes.Axes.scatter)
#
# O grafico de dispersion, nos sirve para observar la relacion entre dos variables, correlacion y su comportamiento.

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N))**2
colors = np.random.rand(N)

plt.style.use('ggplot')
plt.scatter(x, y, s=area, c=colors, alpha=0.6)
plt.colorbar()
# s: cambia el tamaño de cada punto en referencia a una tercera variable
# c: cambia el color de cada punto en referencia a una cuarta variable
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Es una libreria de visualizacion de datos construida sobre Matplotlib.
#
# Esta optimizada para funcionar con pandas asi como Matplotlib lo estaba con numpy.
#
# Ventajas:
# - Velocidad
# - Poco codigo
# - Customizable
#
# Estructura basica:
# ```py
# sns.tipo_grafica(
#     data=df,
#     x='columna1',
#     y='columna2',
#     hue='variable de agrupamiento'
# )
# ```
#
# Tipos de graficas:
# - relplot (relational):
#     - scatterplot
#     - lineplot
# - displot (distributiions):
#     - histplot
#     - kdeplot
#     - ecdfplot
#     - rugplot
# - catplot (categorical)
#     - stripplot
#     - swarmplot
#     - boxplot
#     - violinplot
#     - pointplot
#     - barplot
#
# Ofrece caracteristicas para problemas especificos de visualizacion de datos.
#
# [Overview](https://seaborn.pydata.org/tutorial/function_overview.html)
#
# [Seaborn Cheats](https://deeplearning.fr/seaborn-cheats/)

# %% [markdown]
# ### Set

# %% [markdown]
# Nos permite configurar el estilo del fondo, la paleta de colores, fuente, y tamaño de la fuente.
#
# - Este parámetro afecta a todas las gráficas que creamos, incluidas las que no usan Seaborn.
# - Podemos resetear los valores utilizando el método **reset_orig()**.
# - Este parámetro es un atajo de [set_theme](https://seaborn.pydata.org/generated/seaborn.set_theme.html#seaborn.set_theme), que es el recomendado según la documentación.
# - Otro metodo para cambiar la paleta de colores es [color_palette](https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.reset_orig()
sns.barplot(x=['A','B','C'], y=[1,3,2], hue=['A','B','C'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.reset_orig()
#sns.set(style='darkgrid', palette='flare', font="", font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,3,2], hue=['A','B','C'], palette='flare')
plt.show()

# %% [markdown]
# ### Parametros mas usados con Seaborn

# %% [markdown]
# Seaborn posee un a gran cantidad de graficas, y posee ciertos parametros que son muy utilizados en cada uno de los graficos.
#
# Nota: Puedes usar ’ ; ’ al final de la linea de código para remplazar el 'plt.show()'

# %%
import seaborn as sns
sns.set(rc={"figure.dpi":250}) # configurar la nitidez dpi -> densidad de pixeles
# traer datos de prueba desde seaborn
tips_dataset = sns.load_dataset('tips')

# histograma de la distribucion de total_bill
sns.displot(data=tips_dataset, x='total_bill');

# %%
# Al ingrasarle dos parametros se vuelve un grafico de dispersion
# scatter plot de total_bill vs tip
sns.displot(data=tips_dataset, x='total_bill', y='tip');

# %%
# con hue lo segmentamos por el campo sex
sns.set_style('darkgrid')
sns.displot(data=tips_dataset, x='total_bill', hue='sex', palette='pastel', alpha=0.7);

# %%
# con kind decimos que tipo de grafico vamos a utilizar
# kde es una distribucion por densidad
sns.displot(data=tips_dataset, x='total_bill', hue='sex', kind='kde', legend=False);

# %% [markdown]
# ### Distribuciones

# %% [markdown]
# A continuacion se muestra el tipo de visualizaciones para valores numericos en temas de [ditribucion](https://seaborn.pydata.org/tutorial/distributions.html).

# %%
import seaborn as sns

sns.set_style('darkgrid')
tips_dataset = sns.load_dataset('tips')
tips_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# histograma
sns.histplot(tips_dataset, x='tip', bins=15);
# bins representa el numero de barras de frecuencia

# %%
# histograma con el conteo acumulado
sns.histplot(tips_dataset, x='tip', bins=15, cumulative=True);

# %%
# stat: cambia el tipo de medida del eje y (count, frequency, probability, percent, density)
# multiple: como se presentan los datos en el histograma (layer, stack, dodge, fill)
sns.histplot(tips_dataset, x='tip', bins=15, hue='sex', stat='frequency', multiple='stack');

# %%
# kde o diagrama de densidad
sns.kdeplot(tips_dataset, x='tip', hue='sex');

# %%
# fill: rellena las graficas
# bw_adjust: ajusta los parametros de los ejes
sns.kdeplot(data=tips_dataset, x='tip', hue='sex', fill=True, bw_adjust=1);

# %%
# ecdf o grafico escalonado
# proporcion de las diferentes propinas a lo largo de su frecuencia
sns.ecdfplot(tips_dataset, x='tip', hue='sex', stat='count');

# %%
# dist o diagramas de distribucion
# kind: cambiamos el tipo de grafica de distribucion (hist, kde, ecdf)
sns.displot(tips_dataset, x='tip', hue='sex', stat='count', kind='ecdf');

# %% [markdown]
# ### Categoricos

# %% [markdown]
# Tipos de visualizaciones para variables [categoricas](https://seaborn.pydata.org/tutorial/categorical.html) o de texto.

# %%
import seaborn as sns

tips_dataset = sns.load_dataset('tips')
tips_dataset.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# countplot o grafico de barras
sns.countplot(tips_dataset, x='day', hue='sex');

# %%
sns.countplot(tips_dataset, y='day', hue='sex');

# %%
# stripplot 
# dispersion por dia (day) del total de la cuenta (total_bill)
sns.stripplot(tips_dataset, x='day', y='total_bill', hue='sex');

# %%
sns.stripplot(tips_dataset, x='day', y='total_bill', hue='sex', dodge=True);

# %%
# swamplot
# permite una concentracion en el eje horizontal
sns.swarmplot(tips_dataset, x='day', y='total_bill', hue='sex', dodge=True);

# %%
# boxplot
sns.boxplot(tips_dataset, x='day', y='total_bill', hue='sex');

# %%
# podemos combinar mas de un grafico
sns.swarmplot(tips_dataset, x='day', y='total_bill', hue='sex', dodge=True, palette='flare');
sns.boxplot(tips_dataset, x='day', y='total_bill', hue='sex');

# %%
# violinplot
# muestra como se concentran los datos, es parecido al bloxplot pero sin los cuartiles
sns.violinplot(tips_dataset, x='day', y='total_bill', hue='sex');

# %%
# split: combina en uno solo el hue
sns.violinplot(tips_dataset, x='day', y='total_bill', hue='sex', split=True);

# %%
# catplot
# kind: tipo de gráfico (bar, count, box, swam, etc.)
# col: agregar otra variable para generar otra grafica en base a la variable
sns.catplot(tips_dataset, x='day', y='total_bill', hue='sex', kind='bar', col='time');

# %%
# errorbar (None, sd)
sns.catplot(tips_dataset, x='day', y='total_bill', hue='sex', kind='bar', col='time', errorbar=None);

# %% [markdown]
# ### Relation

# %% [markdown]
# Graficos de tipo [relacion](https://seaborn.pydata.org/generated/seaborn.relplot.html) entre distintas variables. Nos ayudan a ver la relacion o correlacion entre distintas variables numericas.
#
# Un ejemplo de estos son los scatter plot.

# %%
import seaborn as sns

tips_dataset = sns.load_dataset('tips')
tips_dataset.sample(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 44        30.40  5.60    Male     No   Sun  Dinner     4

# %%
# scatterplot
# style: cambia el estilo de los markers segun la variable designada
# size: cambia el tamaño de los markers segun la variable definida
ax = sns.scatterplot(tips_dataset, x='total_bill', y='tip', hue='day', style='time', size='size', palette='Set1');
sns.move_legend(ax, 'upper left', bbox_to_anchor=(1,1))

# %%
# podemos definir los markers a utilizar segun los valores de la variable
markers = {'Lunch': 'D', 'Dinner': 's'}
sns.scatterplot(tips_dataset, x='total_bill', y='tip', 
                hue='day', 
                style='time', 
                size='size', 
                palette='Set1',
                markers=markers
);

# %%
# lineplot
sns.lineplot(tips_dataset, x='total_bill', y='tip', hue='day', style='time', size='size', palette='Set2');

# %%
# relplot
# kind: tipo de gráfico (scatter, line)
sns.relplot(tips_dataset, x='total_bill', y='tip', 
            hue='day', 
            style='time', 
            size='size', 
            palette='Set2',
            kind='line'
);

# %%
# col: agregar otra variable para generar otra grafica en base a la variable
sns.relplot(tips_dataset, x='total_bill', y='tip', 
            hue='day', 
            style='time', 
            size='size', 
            palette='Set2',
            kind='scatter',
            col='time'
);

# %% [markdown]
# ### Joinplot y Pairplot

# %% [markdown]
# Son dos tipos de graficos que son muy utiles en el mundo de la ciencia de datos porque con un unico comando podemos combinar mas de un tipo de grafico.
#
# Son utiles para trabajar con datasets de entrada.
#
# [Joinplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html) une dos distintas graficas en uno solo para poder sacar mas valor analitico.
#
# [Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) muestra las distintas relaciones entre las variables numericas, eligiendo los graficos que seaborn cree mas adecuados.

# %%
import seaborn as sns

tips_dataset = sns.load_dataset('tips')

# dispersion de los datos de total_bill vs tip
# distribucion de cada eje para ver la concentracion de datos
sns.jointplot(tips_dataset, x='total_bill', y='tip');

# %%
sns.jointplot(tips_dataset, x='total_bill', y='tip', hue='sex');

# %%
# podemos cambiar el tipo de visualizacion con kind
sns.jointplot(tips_dataset, x='total_bill', y='tip', hue='sex', kind='hist');

# %%
# marginal_ticks: muestra la escala de las graficas externas
# marginal_kws: cambia la configuracion de las graficas externas
sns.jointplot(tips_dataset, x='total_bill', y='tip', 
            hue='sex', 
            kind='hist', 
            marginal_ticks=True,
            marginal_kws={'bins': 25, 'fill': True, 'multiple': 'stack'}
);

# %%
# pairplot
sns.pairplot(tips_dataset);

# %%
# corner: elimina las graficas que presenten informacion duplicada
sns.pairplot(tips_dataset, hue='sex', palette='flare', corner=True);

# %% [markdown]
# ### Heatmap

# %% [markdown]
# [Heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) es un tipo de grafico muy util para graficar datos en una estructura matricial.

# %%
import seaborn as sns

tips_dataset = sns.load_dataset('tips')

# llevamos el dataset a una estructura matricial
# cor() encuentra la correlacion entre las variables
tips = tips_dataset.corr(numeric_only=True)

sns.heatmap(tips);

# %%
# annot: muestra los valores de la correlacion
# cmap: nos permite cambiar el mapa de colores
# linewidth: da una separacion entre los cuadros
sns.heatmap(tips_dataset.corr(numeric_only=True), 
            annot=True, 
            cmap='crest', 
            linewidth=3,
            linecolor='#333',
);

# %% [markdown]
# Nota: Un tip para cuando se quiera invertir los colores en cmap, es solo agregar “_r” al final del nombre del color usado en cmap.

# %%
# vmin y vmax nos permiten definir los valores minimo y maximo de la correlacion
sns.heatmap(tips_dataset.corr(numeric_only=True), 
            annot=True, 
            linewidth=2,
            vmin=0,
            vmax=1
);
